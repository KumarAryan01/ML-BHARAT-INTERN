# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
iris = pd.read_csv("/content/drive/MyDrive/ML_Bharat_Inter/iris_flower/IRIS.csv")

# %%
iris.head(2)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa

# %%
iris.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris.shape
# Out:
# (150, 5)

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
iris.duplicated().sum()
# Out:
# 3

# %%
sns.pairplot(iris, hue ="species",size = 4)
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:2095: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
fig = iris[iris.species == 'Iris-setosa'].plot.scatter( x ='sepal_length',y = 'sepal_width', color ='orange', label ='Setosa')
iris[iris.species == 'Iris-versicolor'].plot.scatter( x ='sepal_length', y = 'sepal_width', color ='blue', label='versicolor', ax = fig)
iris[iris.species == 'Iris-virginica'].plot.scatter( x = 'sepal_length', y = 'sepal_width', color = 'green', label = 'virginca', ax = fig )

fig.set_xlabel("Sepal Length")
fig.set_ylabel("Sepal Width")
fig.set_title("Sepal Length VS Sepal Width")
fig = plt.gcf()
plt.grid(True)
fig.set_size_inches(10,6)
plt.show()

# %%
fig = iris[iris.species == 'Iris-setosa'].plot.scatter( x = 'petal_length', y = 'petal_width', color = 'orange', label='Setosa')
iris[iris.species == 'Iris-versicolor'].plot.scatter( x = 'petal_length', y = 'petal_width', color = 'blue', label='Versicolor', ax = fig)
iris[iris.species == 'Iris-virginica'].plot.scatter( x = 'petal_length', y = 'petal_width', color = 'green', label='Virginca', ax = fig)
fig.set_xlabel("Petal Length")
fig.set_ylabel("Petal Width")
fig.set_title("Petal Length VS Petal Width")
fig = plt.gcf()
plt.grid(True)
fig.set_size_inches(10,6)
plt.show()

# %%
iris.hist(figsize = (12,6), edgecolor='black')
# Out:
# array([[<Axes: title={'center': 'sepal_length'}>,
#         <Axes: title={'center': 'sepal_width'}>],
#        [<Axes: title={'center': 'petal_length'}>,
#         <Axes: title={'center': 'petal_width'}>]], dtype=object)

# %%
# determining relation between length and width according to species
plt.figure(figsize =(15,10))

plt.subplot(2,2,1)
sns.violinplot(x = 'species', y ='petal_length', data = iris)
plt.subplot(2,2,2)
sns.violinplot(x = 'species', y ='petal_width', data = iris)
plt.subplot(2,2,3)
sns.violinplot(x = 'species', y ='sepal_length', data = iris)
plt.subplot(2,2,4)
sns.violinplot(x = 'species', y ='sepal_width', data = iris)
# Out:
# <Axes: xlabel='species', ylabel='sepal_width'>

# %%
plt.figure(figsize = (11,6))
sns.heatmap(iris.corr(), annot = True, cmap = 'YlGnBu')
plt.show()
# Out:
# <ipython-input-18-3485a88d9df0>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(iris.corr(), annot = True, cmap = 'YlGnBu')

# %%
from sklearn.model_selection import train_test_split
x = iris.drop(["species"], axis = 1)
y = iris["species"]

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.3)

# %%
x_train
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 21            5.1          3.7           1.5          0.4
# 55            5.7          2.8           4.5          1.3
# 63            6.1          2.9           4.7          1.4
# 29            4.7          3.2           1.6          0.2
# 70            5.9          3.2           4.8          1.8
# ..            ...          ...           ...          ...
# 139           6.9          3.1           5.4          2.1
# 135           7.7          3.0           6.1          2.3
# 82            5.8          2.7           3.9          1.2
# 90            5.5          2.6           4.4          1.2
# 106           4.9          2.5           4.5          1.7
#
# [105 rows x 4 columns]

# %%
y_train
# Out:
# 21         Iris-setosa
# 55     Iris-versicolor
# 63     Iris-versicolor
# 29         Iris-setosa
# 70     Iris-versicolor
#             ...
# 139     Iris-virginica
# 135     Iris-virginica
# 82     Iris-versicolor
# 90     Iris-versicolor
# 106     Iris-virginica
# Name: species, Length: 105, dtype: object

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn import metrics

# %% [markdown]
# Logistic Regression

# %%
LR = LogisticRegression()
LR.fit(x_train, y_train)
prediction = LR.predict(x_test)
print("Accuracy Score: ", metrics.accuracy_score(prediction,y_test))
# Out:
# Accuracy Score:  0.9555555555555556

# %% [markdown]
# Decision Tree

# %%
DT = DecisionTreeClassifier()
DT.fit(x_train, y_train)
prediction = DT.predict(x_test)
print("Accuracy Score: ", metrics.accuracy_score(prediction, y_test))
# Out:
# Accuracy Score:  0.9111111111111111

# %%
from sklearn.tree import plot_tree
plt.figure(figsize=(20, 20))
plot_tree(DT, filled=True, feature_names=['sepal_length', 'sepal_width', 'petal_length', 'petal_width'], class_names=iris.species)
plt.title("Decision Tree for Iris Species Classification")
plt.show()
